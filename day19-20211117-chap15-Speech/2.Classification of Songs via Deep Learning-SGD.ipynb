# %%
############################
#For skip data preprocessing
############################
import pandas as pd
sample = pd.read_pickle('data.pickle')
sample[:3]
# Out:
#           filename chroma_stft         rmse   spectral_centroid  \
# 0  blues.00000.wav  0.34994322   0.13022463  1784.4204464946633
# 0  blues.00001.wav   0.3409832  0.095918424  1529.8353159300755
# 0  blues.00002.wav  0.36360285   0.17557304  1552.4819582458863
#
#    spectral_bandwidth             rolloff    zero_crossing_rate       mfcc1  \
# 0  2002.6501916232635  3806.4853160373937   0.08306639113293343  -113.59675
# 0  2038.6175789692213  3548.8202074363876  0.056044256724071206   -207.5568
# 0  1747.1659849613065   3040.514947755418   0.07630074799245357   -90.75439
#
#        mfcc2       mfcc3  ...    mfcc12      mfcc13     mfcc14      mfcc15  \
# 0   121.5573  -19.158825  ...  8.810669  -3.6673682   5.751691  -5.1627626
# 0  124.00672     8.93056  ...  5.376803  -2.2391195  4.2169633  -6.0122733
# 0   140.4599  -29.109964  ...  5.789265   -8.905224   -1.08372   -9.218358
#
#        mfcc16       mfcc17       mfcc18      mfcc19      mfcc20  style
# 0  0.75094783   -1.6919376  -0.40995264  -2.3002088   1.2199285  blues
# 0   0.9361094  -0.71653724   0.29387605  -0.2874308   0.5315728  blues
# 0    2.455806    -7.726901    -1.815723  -3.4334342  -2.2268214  blues
#
# [3 rows x 28 columns]

# %%
# X, y
# y <-- one-hot encoder or label encoder
# X <-- data type astype('float32')
# standarization(optional)
# train_test_split
# build model with algorithm
# model.fit
# model.score & model.predict

# %%
# y 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_raw = sample.iloc[:, -1].values
y = le.fit_transform(y_raw)
y[:3]
# Out:
# array([0, 0, 0])

# %%
# X 頭filename　尾style　不要
X = sample.iloc[:, 1:-1].values.astype('float32')
X[:3]
# Out:
# array([[ 3.49943221e-01,  1.30224630e-01,  1.78442041e+03,
#          2.00265015e+03,  3.80648535e+03,  8.30663890e-02,
#         -1.13596748e+02,  1.21557297e+02, -1.91588249e+01,
#          4.23510323e+01, -6.37645817e+00,  1.86188755e+01,
#         -1.36979113e+01,  1.53446312e+01, -1.22852669e+01,
#          1.09804916e+01, -8.32432461e+00,  8.81066895e+00,
#         -3.66736817e+00,  5.75169086e+00, -5.16276264e+00,
#          7.50947833e-01, -1.69193757e+00, -4.09952641e-01,
#         -2.30020881e+00,  1.21992850e+00],
#        [ 3.40983212e-01,  9.59184244e-02,  1.52983533e+03,
#          2.03861755e+03,  3.54882031e+03,  5.60442582e-02,
#         -2.07556793e+02,  1.24006721e+02,  8.93056011e+00,
#          3.58746872e+01,  2.91603684e+00,  2.15237255e+01,
#         -8.55470371e+00,  2.33586712e+01, -1.01036167e+01,
#          1.19037437e+01, -5.56038809e+00,  5.37680292e+00,
#         -2.23911953e+00,  4.21696329e+00, -6.01227331e+00,
#          9.36109424e-01, -7.16537237e-01,  2.93876052e-01,
#         -2.87430793e-01,  5.31572819e-01],
#        [ 3.63602847e-01,  1.75573036e-01,  1.55248193e+03,
#          1.74716602e+03,  3.04051489e+03,  7.63007477e-02,
#         -9.07543869e+01,  1.40459900e+02, -2.91099644e+01,
#          3.16890144e+01, -1.39870358e+01,  2.57547588e+01,
#         -1.36495867e+01,  1.16292715e+01, -1.17805891e+01,
#          9.70644283e+00, -1.31231108e+01,  5.78926516e+00,
#         -8.90522385e+00, -1.08371997e+00, -9.21835804e+00,
#          2.45580602e+00, -7.72690105e+00, -1.81572294e+00,
#         -3.43343425e+00, -2.22682142e+00]], dtype=float32)

# %%
# 加入資料前處理
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_ss = ss.fit_transform(X)

# %%
# 分割數據
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_ss, y, test_size=0.2, random_state=42)

# %%
# 確認數據種類 & 個數
import numpy as np
np.bincount(y_train)
# Out:
# array([80, 87, 73, 79, 85, 78, 75, 87, 77, 79], dtype=int64)

# %%
# 導入函式庫
import numpy as np  
import keras
from keras.layers import Dense, Activation #神經層
from keras.utils import np_utils           # 用來後續將 label 標籤轉為 one-hot-encoding  


# 建立簡單的線性執行的模型
model = keras.models.Sequential()

# Add Input layer, 隱藏層(hidden layer) 有 256個輸出變數
model.add(Dense(units=256, input_dim=X_train.shape[1], 
                kernel_initializer='normal', activation='relu'))             # input + hidder layer
model.add(Dense(units=128, kernel_initializer='normal', activation='relu'))  # hidder layer
model.add(Dense(units=64, kernel_initializer='normal', activation='relu'))  # hidder layer
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))# Add output layer


# 編譯: 選擇損失函數、優化方法及成效衡量方式 sparse_categorical_crossentropy categorical_crossentropy
# RMSProp  SGD
model.compile(loss='categorical_crossentropy', optimizer='SGD', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 256)               6912
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                650
# =================================================================
# Total params: 48,714
# Trainable params: 48,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_TrainOneHot = np_utils.to_categorical(y_train).astype('int32')
y_TestOneHot = np_utils.to_categorical(y_test).astype('int32')

# %%
X_train.shape
# Out:
# (800, 26)

# %%
# 進行訓練, 訓練過程會存在 train_history 變數中
train_history = model.fit(x=X_train, 
                          y=y_TrainOneHot, 
                          validation_split=0.2, 
                          epochs=150, 
                          batch_size=10, 
                          verbose=2)  

print('Done!!')
# Out:
# Epoch 1/150
# 64/64 - 1s - loss: 2.2990 - accuracy: 0.1797 - val_loss: 2.2989 - val_accuracy: 0.1750
# Epoch 2/150
# 64/64 - 1s - loss: 2.2946 - accuracy: 0.2703 - val_loss: 2.2962 - val_accuracy: 0.2250
# Epoch 3/150
# 64/64 - 2s - loss: 2.2900 - accuracy: 0.2422 - val_loss: 2.2931 - val_accuracy: 0.2375
# Epoch 4/150
# 64/64 - 1s - loss: 2.2847 - accuracy: 0.2734 - val_loss: 2.2893 - val_accuracy: 0.2625
# Epoch 5/150
# 64/64 - 1s - loss: 2.2784 - accuracy: 0.3078 - val_loss: 2.2846 - val_accuracy: 0.2688
# Epoch 6/150
# 64/64 - 1s - loss: 2.2704 - accuracy: 0.3063 - val_loss: 2.2782 - val_accuracy: 0.2688
# Epoch 7/150
# 64/64 - 1s - loss: 2.2601 - accuracy: 0.3063 - val_loss: 2.2696 - val_accuracy: 0.2688
# Epoch 8/150
# 64/64 - 1s - loss: 2.2461 - accuracy: 0.3109 - val_loss: 2.2575 - val_accuracy: 0.2750
# Epoch 9/150
# 64/64 - 1s - loss: 2.2265 - accuracy: 0.3031 - val_loss: 2.2403 - val_accuracy: 0.2688
# Epoch 10/150
# 64/64 - 1s - loss: 2.1987 - accuracy: 0.2984 - val_loss: 2.2156 - val_accuracy: 0.2688
# Epoch 11/150
# 64/64 - 1s - loss: 2.1596 - accuracy: 0.3047 - val_loss: 2.1815 - val_accuracy: 0.2625
# Epoch 12/150
# 64/64 - 1s - loss: 2.1081 - accuracy: 0.3031 - val_loss: 2.1383 - val_accuracy: 0.2625
# Epoch 13/150
# 64/64 - 1s - loss: 2.0490 - accuracy: 0.3063 - val_loss: 2.0905 - val_accuracy: 0.2688
# Epoch 14/150
# 64/64 - 1s - loss: 1.9890 - accuracy: 0.3078 - val_loss: 2.0394 - val_accuracy: 0.2688
# Epoch 15/150
# 64/64 - 1s - loss: 1.9300 - accuracy: 0.3094 - val_loss: 1.9857 - val_accuracy: 0.2688
# Epoch 16/150
# 64/64 - 1s - loss: 1.8725 - accuracy: 0.3141 - val_loss: 1.9306 - val_accuracy: 0.2688
# Epoch 17/150
# 64/64 - 1s - loss: 1.8176 - accuracy: 0.3266 - val_loss: 1.8752 - val_accuracy: 0.2812
# Epoch 18/150
# 64/64 - 1s - loss: 1.7671 - accuracy: 0.3344 - val_loss: 1.8285 - val_accuracy: 0.2812
# Epoch 19/150
# 64/64 - 1s - loss: 1.7251 - accuracy: 0.3469 - val_loss: 1.7872 - val_accuracy: 0.2875
# Epoch 20/150
# 64/64 - 1s - loss: 1.6878 - accuracy: 0.3500 - val_loss: 1.7523 - val_accuracy: 0.2937
# Epoch 21/150
# 64/64 - 1s - loss: 1.6560 - accuracy: 0.3500 - val_loss: 1.7219 - val_accuracy: 0.3000
# Epoch 22/150
# 64/64 - 1s - loss: 1.6247 - accuracy: 0.3609 - val_loss: 1.6945 - val_accuracy: 0.3250
# Epoch 23/150
# 64/64 - 1s - loss: 1.5969 - accuracy: 0.3672 - val_loss: 1.6662 - val_accuracy: 0.3375
# Epoch 24/150
# 64/64 - 1s - loss: 1.5699 - accuracy: 0.3812 - val_loss: 1.6434 - val_accuracy: 0.3438
# Epoch 25/150
# 64/64 - 1s - loss: 1.5472 - accuracy: 0.3969 - val_loss: 1.6235 - val_accuracy: 0.3438
# Epoch 26/150
# 64/64 - 1s - loss: 1.5230 - accuracy: 0.3906 - val_loss: 1.6007 - val_accuracy: 0.3313
# Epoch 27/150
# 64/64 - 1s - loss: 1.4993 - accuracy: 0.4031 - val_loss: 1.5765 - val_accuracy: 0.3812
# Epoch 28/150
# 64/64 - 1s - loss: 1.4758 - accuracy: 0.4313 - val_loss: 1.5571 - val_accuracy: 0.3688
# Epoch 29/150
# 64/64 - 1s - loss: 1.4511 - accuracy: 0.4281 - val_loss: 1.5421 - val_accuracy: 0.3750
# Epoch 30/150
# 64/64 - 1s - loss: 1.4292 - accuracy: 0.4547 - val_loss: 1.5101 - val_accuracy: 0.3938
# Epoch 31/150
# 64/64 - 1s - loss: 1.4057 - accuracy: 0.4547 - val_loss: 1.5056 - val_accuracy: 0.3875
# Epoch 32/150
# 64/64 - 1s - loss: 1.3853 - accuracy: 0.4734 - val_loss: 1.4766 - val_accuracy: 0.4187
# Epoch 33/150
# 64/64 - 1s - loss: 1.3586 - accuracy: 0.4797 - val_loss: 1.4512 - val_accuracy: 0.4563
# Epoch 34/150
# 64/64 - 1s - loss: 1.3422 - accuracy: 0.4875 - val_loss: 1.4436 - val_accuracy: 0.4625
# Epoch 35/150
# 64/64 - 1s - loss: 1.3181 - accuracy: 0.5016 - val_loss: 1.4186 - val_accuracy: 0.4500
# Epoch 36/150
# 64/64 - 2s - loss: 1.2957 - accuracy: 0.5094 - val_loss: 1.3968 - val_accuracy: 0.4812
# Epoch 37/150
# 64/64 - 1s - loss: 1.2746 - accuracy: 0.5109 - val_loss: 1.3784 - val_accuracy: 0.4875
# Epoch 38/150
# 64/64 - 2s - loss: 1.2493 - accuracy: 0.5312 - val_loss: 1.3726 - val_accuracy: 0.5188
# Epoch 39/150
# 64/64 - 1s - loss: 1.2293 - accuracy: 0.5547 - val_loss: 1.3449 - val_accuracy: 0.5000
# Epoch 40/150
# 64/64 - 1s - loss: 1.2031 - accuracy: 0.5688 - val_loss: 1.3556 - val_accuracy: 0.5188
# Epoch 41/150
# 64/64 - 0s - loss: 1.1879 - accuracy: 0.5688 - val_loss: 1.3098 - val_accuracy: 0.5312
# Epoch 42/150
# 64/64 - 1s - loss: 1.1631 - accuracy: 0.5766 - val_loss: 1.3023 - val_accuracy: 0.5500
# Epoch 43/150
# 64/64 - 2s - loss: 1.1437 - accuracy: 0.5906 - val_loss: 1.2873 - val_accuracy: 0.5437
# Epoch 44/150
# 64/64 - 1s - loss: 1.1167 - accuracy: 0.6094 - val_loss: 1.2658 - val_accuracy: 0.5437
# Epoch 45/150
# 64/64 - 1s - loss: 1.1003 - accuracy: 0.6078 - val_loss: 1.2594 - val_accuracy: 0.5312
# Epoch 46/150
# 64/64 - 1s - loss: 1.0885 - accuracy: 0.6125 - val_loss: 1.2528 - val_accuracy: 0.5813
# Epoch 47/150
# 64/64 - 0s - loss: 1.0709 - accuracy: 0.6203 - val_loss: 1.2592 - val_accuracy: 0.5437
# Epoch 48/150
# 64/64 - 0s - loss: 1.0494 - accuracy: 0.6250 - val_loss: 1.2360 - val_accuracy: 0.5875
# Epoch 49/150
# 64/64 - 0s - loss: 1.0380 - accuracy: 0.6359 - val_loss: 1.2140 - val_accuracy: 0.5688
# Epoch 50/150
# 64/64 - 1s - loss: 1.0118 - accuracy: 0.6406 - val_loss: 1.1986 - val_accuracy: 0.6062
# Epoch 51/150
# 64/64 - 1s - loss: 1.0084 - accuracy: 0.6438 - val_loss: 1.2004 - val_accuracy: 0.5938
# Epoch 52/150
# 64/64 - 1s - loss: 0.9942 - accuracy: 0.6484 - val_loss: 1.1985 - val_accuracy: 0.6000
# Epoch 53/150
# 64/64 - 1s - loss: 0.9754 - accuracy: 0.6531 - val_loss: 1.1766 - val_accuracy: 0.6062
# Epoch 54/150
# 64/64 - 1s - loss: 0.9582 - accuracy: 0.6531 - val_loss: 1.2017 - val_accuracy: 0.6125
# Epoch 55/150
# 64/64 - 1s - loss: 0.9429 - accuracy: 0.6484 - val_loss: 1.1594 - val_accuracy: 0.6062
# Epoch 56/150
# 64/64 - 1s - loss: 0.9352 - accuracy: 0.6625 - val_loss: 1.1739 - val_accuracy: 0.6062
# Epoch 57/150
# 64/64 - 1s - loss: 0.9247 - accuracy: 0.6656 - val_loss: 1.1636 - val_accuracy: 0.5875
# Epoch 58/150
# 64/64 - 1s - loss: 0.9032 - accuracy: 0.6781 - val_loss: 1.1480 - val_accuracy: 0.6250
# Epoch 59/150
# 64/64 - 1s - loss: 0.8898 - accuracy: 0.6719 - val_loss: 1.1490 - val_accuracy: 0.6062
# Epoch 60/150
# 64/64 - 1s - loss: 0.8765 - accuracy: 0.6859 - val_loss: 1.1386 - val_accuracy: 0.6000
# Epoch 61/150
# 64/64 - 1s - loss: 0.8639 - accuracy: 0.6922 - val_loss: 1.1319 - val_accuracy: 0.6187
# Epoch 62/150
# 64/64 - 1s - loss: 0.8494 - accuracy: 0.7000 - val_loss: 1.1561 - val_accuracy: 0.6125
# Epoch 63/150
# 64/64 - 1s - loss: 0.8355 - accuracy: 0.7109 - val_loss: 1.1373 - val_accuracy: 0.6313
# Epoch 64/150
# 64/64 - 1s - loss: 0.8228 - accuracy: 0.7063 - val_loss: 1.1190 - val_accuracy: 0.6375
# Epoch 65/150
# 64/64 - 0s - loss: 0.8106 - accuracy: 0.7188 - val_loss: 1.1592 - val_accuracy: 0.6125
# Epoch 66/150
# 64/64 - 1s - loss: 0.7922 - accuracy: 0.7219 - val_loss: 1.1257 - val_accuracy: 0.6250
# Epoch 67/150
# 64/64 - 1s - loss: 0.7826 - accuracy: 0.7234 - val_loss: 1.1431 - val_accuracy: 0.6062
# Epoch 68/150
# 64/64 - 1s - loss: 0.7691 - accuracy: 0.7406 - val_loss: 1.1159 - val_accuracy: 0.6313
# Epoch 69/150
# 64/64 - 1s - loss: 0.7551 - accuracy: 0.7234 - val_loss: 1.1273 - val_accuracy: 0.6313
# Epoch 70/150
# 64/64 - 1s - loss: 0.7453 - accuracy: 0.7547 - val_loss: 1.1380 - val_accuracy: 0.6250
# Epoch 71/150
# 64/64 - 1s - loss: 0.7258 - accuracy: 0.7516 - val_loss: 1.1353 - val_accuracy: 0.6125
# Epoch 72/150
# 64/64 - 1s - loss: 0.7226 - accuracy: 0.7500 - val_loss: 1.1353 - val_accuracy: 0.6313
# Epoch 73/150
# 64/64 - 1s - loss: 0.7092 - accuracy: 0.7641 - val_loss: 1.1410 - val_accuracy: 0.6438
# Epoch 74/150
# 64/64 - 1s - loss: 0.6946 - accuracy: 0.7672 - val_loss: 1.1580 - val_accuracy: 0.6250
# Epoch 75/150
# 64/64 - 1s - loss: 0.6855 - accuracy: 0.7734 - val_loss: 1.1260 - val_accuracy: 0.6187
# Epoch 76/150
# 64/64 - 1s - loss: 0.6633 - accuracy: 0.7797 - val_loss: 1.1324 - val_accuracy: 0.6250
# Epoch 77/150
# 64/64 - 1s - loss: 0.6539 - accuracy: 0.7859 - val_loss: 1.1472 - val_accuracy: 0.6187
# Epoch 78/150
# 64/64 - 1s - loss: 0.6448 - accuracy: 0.7891 - val_loss: 1.1207 - val_accuracy: 0.6438
# Epoch 79/150
# 64/64 - 1s - loss: 0.6341 - accuracy: 0.7953 - val_loss: 1.1252 - val_accuracy: 0.6187
# Epoch 80/150
# 64/64 - 1s - loss: 0.6293 - accuracy: 0.7922 - val_loss: 1.1417 - val_accuracy: 0.6250
# Epoch 81/150
# 64/64 - 1s - loss: 0.6018 - accuracy: 0.8047 - val_loss: 1.1374 - val_accuracy: 0.6375
# Epoch 82/150
# 64/64 - 1s - loss: 0.6001 - accuracy: 0.7859 - val_loss: 1.1457 - val_accuracy: 0.6438
# Epoch 83/150
# 64/64 - 2s - loss: 0.5870 - accuracy: 0.8031 - val_loss: 1.1222 - val_accuracy: 0.6500
# Epoch 84/150
# 64/64 - 1s - loss: 0.5726 - accuracy: 0.8031 - val_loss: 1.1354 - val_accuracy: 0.6313
# Epoch 85/150
# 64/64 - 1s - loss: 0.5671 - accuracy: 0.8094 - val_loss: 1.1382 - val_accuracy: 0.6375
# Epoch 86/150
# 64/64 - 1s - loss: 0.5523 - accuracy: 0.8047 - val_loss: 1.1368 - val_accuracy: 0.6500
# Epoch 87/150
# 64/64 - 1s - loss: 0.5420 - accuracy: 0.8297 - val_loss: 1.1339 - val_accuracy: 0.6438
# Epoch 88/150
# 64/64 - 1s - loss: 0.5328 - accuracy: 0.8219 - val_loss: 1.1463 - val_accuracy: 0.6500
# Epoch 89/150
# 64/64 - 1s - loss: 0.5054 - accuracy: 0.8453 - val_loss: 1.1761 - val_accuracy: 0.6125
# Epoch 90/150
# 64/64 - 1s - loss: 0.5072 - accuracy: 0.8328 - val_loss: 1.1392 - val_accuracy: 0.6500
# Epoch 91/150
# 64/64 - 1s - loss: 0.4945 - accuracy: 0.8406 - val_loss: 1.1464 - val_accuracy: 0.6438
# Epoch 92/150
# 64/64 - 1s - loss: 0.4846 - accuracy: 0.8484 - val_loss: 1.1551 - val_accuracy: 0.6313
# Epoch 93/150
# 64/64 - 1s - loss: 0.4739 - accuracy: 0.8406 - val_loss: 1.1851 - val_accuracy: 0.6562
# Epoch 94/150
# 64/64 - 1s - loss: 0.4530 - accuracy: 0.8531 - val_loss: 1.1905 - val_accuracy: 0.6375
# Epoch 95/150
# 64/64 - 1s - loss: 0.4611 - accuracy: 0.8422 - val_loss: 1.1553 - val_accuracy: 0.6562
# Epoch 96/150
# 64/64 - 1s - loss: 0.4374 - accuracy: 0.8641 - val_loss: 1.1596 - val_accuracy: 0.6375
# Epoch 97/150
# 64/64 - 1s - loss: 0.4307 - accuracy: 0.8656 - val_loss: 1.1844 - val_accuracy: 0.6438
# Epoch 98/150
# 64/64 - 1s - loss: 0.4208 - accuracy: 0.8625 - val_loss: 1.1670 - val_accuracy: 0.6687
# Epoch 99/150
# 64/64 - 1s - loss: 0.4146 - accuracy: 0.8672 - val_loss: 1.1603 - val_accuracy: 0.6438
# Epoch 100/150
# 64/64 - 1s - loss: 0.4052 - accuracy: 0.8672 - val_loss: 1.2137 - val_accuracy: 0.6375
# Epoch 101/150
# 64/64 - 1s - loss: 0.3979 - accuracy: 0.8766 - val_loss: 1.1866 - val_accuracy: 0.6500
# Epoch 102/150
# 64/64 - 1s - loss: 0.3884 - accuracy: 0.8719 - val_loss: 1.1929 - val_accuracy: 0.6687
# Epoch 103/150
# 64/64 - 1s - loss: 0.3720 - accuracy: 0.8875 - val_loss: 1.2021 - val_accuracy: 0.6500
# Epoch 104/150
# 64/64 - 1s - loss: 0.3651 - accuracy: 0.8891 - val_loss: 1.1956 - val_accuracy: 0.6625
# Epoch 105/150
# 64/64 - 1s - loss: 0.3581 - accuracy: 0.8875 - val_loss: 1.2145 - val_accuracy: 0.6562
# Epoch 106/150
# 64/64 - 1s - loss: 0.3468 - accuracy: 0.8969 - val_loss: 1.1920 - val_accuracy: 0.6562
# Epoch 107/150
# 64/64 - 1s - loss: 0.3374 - accuracy: 0.8953 - val_loss: 1.2229 - val_accuracy: 0.6625
# Epoch 108/150
# 64/64 - 1s - loss: 0.3343 - accuracy: 0.8891 - val_loss: 1.2327 - val_accuracy: 0.6500
# Epoch 109/150
# 64/64 - 1s - loss: 0.3262 - accuracy: 0.8984 - val_loss: 1.2270 - val_accuracy: 0.6562
# Epoch 110/150
# 64/64 - 1s - loss: 0.3143 - accuracy: 0.8969 - val_loss: 1.2730 - val_accuracy: 0.6625
# Epoch 111/150
# 64/64 - 1s - loss: 0.3064 - accuracy: 0.9016 - val_loss: 1.2797 - val_accuracy: 0.6438
# Epoch 112/150
# 64/64 - 1s - loss: 0.3038 - accuracy: 0.9109 - val_loss: 1.2540 - val_accuracy: 0.6625
# Epoch 113/150
# 64/64 - 1s - loss: 0.2843 - accuracy: 0.9234 - val_loss: 1.2711 - val_accuracy: 0.6562
# Epoch 114/150
# 64/64 - 1s - loss: 0.2871 - accuracy: 0.9109 - val_loss: 1.2793 - val_accuracy: 0.6500
# Epoch 115/150
# 64/64 - 1s - loss: 0.2718 - accuracy: 0.9203 - val_loss: 1.3462 - val_accuracy: 0.6500
# Epoch 116/150
# 64/64 - 1s - loss: 0.2675 - accuracy: 0.9234 - val_loss: 1.3424 - val_accuracy: 0.6625
# Epoch 117/150
# 64/64 - 1s - loss: 0.2710 - accuracy: 0.9141 - val_loss: 1.3103 - val_accuracy: 0.6812
# Epoch 118/150
# 64/64 - 1s - loss: 0.2573 - accuracy: 0.9234 - val_loss: 1.3078 - val_accuracy: 0.6875
# Epoch 119/150
# 64/64 - 1s - loss: 0.2479 - accuracy: 0.9266 - val_loss: 1.3305 - val_accuracy: 0.6812
# Epoch 120/150
# 64/64 - 1s - loss: 0.2503 - accuracy: 0.9250 - val_loss: 1.3147 - val_accuracy: 0.6875
# Epoch 121/150
# 64/64 - 1s - loss: 0.2358 - accuracy: 0.9312 - val_loss: 1.3689 - val_accuracy: 0.6438
# Epoch 122/150
# 64/64 - 1s - loss: 0.2284 - accuracy: 0.9391 - val_loss: 1.3831 - val_accuracy: 0.6562
# Epoch 123/150
# 64/64 - 1s - loss: 0.2288 - accuracy: 0.9344 - val_loss: 1.3579 - val_accuracy: 0.6938
# Epoch 124/150
# 64/64 - 1s - loss: 0.2219 - accuracy: 0.9406 - val_loss: 1.3663 - val_accuracy: 0.6562
# Epoch 125/150
# 64/64 - 1s - loss: 0.2105 - accuracy: 0.9516 - val_loss: 1.3846 - val_accuracy: 0.6625
# Epoch 126/150
# 64/64 - 1s - loss: 0.2072 - accuracy: 0.9469 - val_loss: 1.3910 - val_accuracy: 0.6438
# Epoch 127/150
# 64/64 - 1s - loss: 0.2030 - accuracy: 0.9453 - val_loss: 1.4230 - val_accuracy: 0.6750
# Epoch 128/150
# 64/64 - 1s - loss: 0.2003 - accuracy: 0.9469 - val_loss: 1.4207 - val_accuracy: 0.6562
# Epoch 129/150
# 64/64 - 1s - loss: 0.1951 - accuracy: 0.9516 - val_loss: 1.4119 - val_accuracy: 0.6750
# Epoch 130/150
# 64/64 - 1s - loss: 0.1860 - accuracy: 0.9469 - val_loss: 1.4457 - val_accuracy: 0.6750
# Epoch 131/150
# 64/64 - 1s - loss: 0.1825 - accuracy: 0.9500 - val_loss: 1.4354 - val_accuracy: 0.6750
# Epoch 132/150
# 64/64 - 1s - loss: 0.1743 - accuracy: 0.9578 - val_loss: 1.4394 - val_accuracy: 0.6750
# Epoch 133/150
# 64/64 - 1s - loss: 0.1746 - accuracy: 0.9516 - val_loss: 1.4294 - val_accuracy: 0.6687
# Epoch 134/150
# 64/64 - 1s - loss: 0.1667 - accuracy: 0.9625 - val_loss: 1.4394 - val_accuracy: 0.6625
# Epoch 135/150
# 64/64 - 1s - loss: 0.1617 - accuracy: 0.9609 - val_loss: 1.5120 - val_accuracy: 0.6500
# Epoch 136/150
# 64/64 - 1s - loss: 0.1611 - accuracy: 0.9656 - val_loss: 1.4753 - val_accuracy: 0.6750
# Epoch 137/150
# 64/64 - 1s - loss: 0.1532 - accuracy: 0.9688 - val_loss: 1.4880 - val_accuracy: 0.6625
# Epoch 138/150
# 64/64 - 1s - loss: 0.1453 - accuracy: 0.9672 - val_loss: 1.5190 - val_accuracy: 0.6750
# Epoch 139/150
# 64/64 - 1s - loss: 0.1436 - accuracy: 0.9703 - val_loss: 1.5708 - val_accuracy: 0.6375
# Epoch 140/150
# 64/64 - 1s - loss: 0.1456 - accuracy: 0.9719 - val_loss: 1.5877 - val_accuracy: 0.6687
# Epoch 141/150
# 64/64 - 1s - loss: 0.1393 - accuracy: 0.9750 - val_loss: 1.5324 - val_accuracy: 0.6812
# Epoch 142/150
# 64/64 - 1s - loss: 0.1329 - accuracy: 0.9766 - val_loss: 1.5964 - val_accuracy: 0.6500
# Epoch 143/150
# 64/64 - 1s - loss: 0.1312 - accuracy: 0.9766 - val_loss: 1.5585 - val_accuracy: 0.6750
# Epoch 144/150
# 64/64 - 1s - loss: 0.1246 - accuracy: 0.9734 - val_loss: 1.5561 - val_accuracy: 0.6687
# Epoch 145/150
# 64/64 - 1s - loss: 0.1283 - accuracy: 0.9766 - val_loss: 1.5714 - val_accuracy: 0.6500
# Epoch 146/150
# 64/64 - 1s - loss: 0.1180 - accuracy: 0.9719 - val_loss: 1.6590 - val_accuracy: 0.6375
# Epoch 147/150
# 64/64 - 1s - loss: 0.1179 - accuracy: 0.9719 - val_loss: 1.6377 - val_accuracy: 0.6375
# Epoch 148/150
# 64/64 - 1s - loss: 0.1204 - accuracy: 0.9750 - val_loss: 1.6443 - val_accuracy: 0.6625
# Epoch 149/150
# 64/64 - 1s - loss: 0.1102 - accuracy: 0.9828 - val_loss: 1.6210 - val_accuracy: 0.6750
# Epoch 150/150
# 64/64 - 1s - loss: 0.1096 - accuracy: 0.9828 - val_loss: 1.6343 - val_accuracy: 0.6750
# Done!!

# %%
scores = model.evaluate(X_test, y_TestOneHot)  
print()  
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
# Out:
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9544 - accuracy: 0.6050
#
# 	[Info] Accuracy of testing data = 60.5%

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(train_history.history['loss'], color='red')
plt.plot(train_history.history['val_loss'], color='blue')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(train_history.history['accuracy'], color='red')
plt.plot(train_history.history['val_accuracy'], color='blue')
plt.show()
