# %%
# 講解
# https://en.wikipedia.org/wiki/Kernel_(image_processing)
# import data
import matplotlib.pyplot as plt
from scipy import misc, signal 
import numpy as np

kernel = np.array([[0, -1, 0], 
                   [-1, 5, -1], 
                   [0, -1, 0]])
img = (plt.imread('andy3.jpg'))
img.shape
# Out:
# (259, 195, 3)

# %%
# Reference
img_sharpened = np.ones(img.shape)
for i in range(3): # 3 : RGB # [..., 0]
    img_sharpened[...,i] = np.clip(signal.convolve2d(img[...,i], 
                                                     kernel, 
                                                     mode='same', 
                                                     boundary="fill"), 0, 1)

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(6, 6))
ax[0].imshow(img)
ax[0].set_title('Original Image', size=12)
ax[1].imshow(img_sharpened)
ax[1].set_title('Convolve2d Image', size=12)
plt.show()

# %%
#################################
# 怎樣處理 RGB 
#################################

# %%
kernel = np.array([[0, -1, 0], 
                   [-1, 5, -1], 
                   [0, -1, 0]])
from skimage import color
andy_gray = color.rgb2gray(img)  # 這裡是黑白!!!

height, width = img.shape[0]-3+1, img.shape[1]-3+1
conv = np.zeros((height, width))
for ii in range(height):
    for jj in range(width):
        val = np.sum(kernel * img[ii:ii+3, jj:jj+3])
        conv[ii, jj] = val


fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(6, 6))
ax[0].imshow(img)
ax[0].set_title('Original Image', size=12)
ax[1].imshow(conv, cmap='gray')
ax[1].set_title('Convolve2d Image', size=12)
plt.show()

# %%
conv.shape

# %%
# RGB

kernel = np.array([[0, -1, 0], 
                   [-1, 5, -1], 
                   [0, -1, 0]])
img = (plt.imread('andy3.jpg'))

img.shape
# Out:
# (259, 195, 3)

# %%
img[..., 1].shape
# Out:
# (259, 195)

# %%
im_r = img[...,0]
height, width = img.shape[0]-3+1, img.shape[1]-3+1
conv_r = np.zeros((height, width))
for ii in range(height):
    for jj in range(width):
        val = np.sum(kernel * im_r[ii:ii+3, jj:jj+3])
        conv_r[ii, jj] = val

im_g = img[...,1]
height, width = img.shape[0]-3+1, img.shape[1]-3+1
conv_g = np.zeros((height, width))
for ii in range(height):
    for jj in range(width):
        val = np.sum(kernel * im_g[ii:ii+3, jj:jj+3])
        conv_g[ii, jj] = val
        
im_b = img[...,2]
height, width = img.shape[0]-3+1, img.shape[1]-3+1
conv_b = np.zeros((height, width))
for ii in range(height):
    for jj in range(width):
        val = np.sum(kernel * im_b[ii:ii+3, jj:jj+3])
        conv_b[ii, jj] = val

print(conv_r.shape)         
print(conv_g.shape)
print(conv_b.shape)


# from PIL import Image
# import numpy as np
# img = Image.fromarray(pic)    
    
# fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(6, 6))
# ax[0].imshow(img)
# ax[0].set_title('Original Image', size=12)
# ax[1].imshow(pic)
# ax[1].set_title('Convolve2d Image', size=12)
# plt.show()
# Out:
# (257, 193)
# (257, 193)
# (257, 193)

# %%
# by Lewis
conv_rgb = np.zeros((height, width, 3))
conv_rgb[..., 0] = conv_r
conv_rgb[..., 1] = conv_g
conv_rgb[..., 2] = conv_b
conv_rgb.shape
# Out:
# (257, 193, 3)

# %%
# by Lewis
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(6, 6))
ax[0].imshow(img)
ax[0].set_title('Original Image', size=12)
ax[1].imshow(np.clip(conv_rgb, 0, 1))
ax[1].set_title('Convolve2d Image', size=12)
plt.show()

# %%
pic = np.dstack((conv_r, conv_g, conv_b))
print(pic.shape)

# img_new = Image.fromarray(pic)
# Image.fromarray?

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(6, 6))
ax[0].imshow(img)
ax[0].set_title('Original Image', size=12)
ax[1].imshow(pic)
ax[1].set_title('Convolve2d Image', size=12)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (257, 193, 3)

# %%
np.concatenate?

# %%
np.dstack?
# Stack arrays in sequence depth wise (along third axis).

# %%
a = np.array([[1],[2],[3]])
b = np.array([[2],[3],[4]])
print(a.shape, b.shape)
c = np.dstack((a,b))
print(c)
c.shape

# %%
c[..., 0]

# %%
np.dstack(a)

# %%
# !pip install pillow

# %%
# !pip install opencv-python-headless
